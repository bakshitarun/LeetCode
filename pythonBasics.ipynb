# %%
#\ will help you concatenate all the lines in print
print(""" I am working \
on \
something \
new""")
# Out:
#  I am working on something new

# %%
print(""" I am working 
on 
something 
new""")
# Out:
#  I am working
# on
# something
# new

# %%
print(r"this will help me to print \ character as well")
# Out:
# this will help me to print \ character as well

# %%
print("this will help me to print \\ character as well")
# Out:
# this will help me to print \ character as well
