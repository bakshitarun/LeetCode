# %%
import pandas as pd
import numpy as np

# %%
lists = '''
  id integer default id_seq.nextval, 
  name varchar(100) not null
  '''

# %%
for i in lists:
  print(i)
# Out:
#
#
# i
# d
#
# i
# n
# t
# e
# g
# e
# r
#
# d
# e
# f
# a
# u
# l
# t
#
# i
# d
# _
# s
# e
# q
# .
# n
# e
# x
# t
# v
# a
# l
# ,
#
#
#
#
#
# n
# a
# m
# e
#
# v
# a
# r
# c
# h
# a
# r
# (
# 1
# 0
# 0
# )
#
# n
# o
# t
#
# n
# u
# l
# l

# %%
import random
randomlist = []
for i in range(0,5):
  n = random.randint(1,30)
  randomlist.append(n)
print(randomlist)
# Out:
# [24, 11, 16, 27, 19]

# %%
for i in range(100):
  print()
